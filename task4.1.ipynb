# %%
#step1:-Import numpy to create a 2D array and cv2 module is used for display image
import numpy as np
import cv2

# %%
img=np.zeros((250,200))
#Display image
cv2.imshow("img1",img);
cv2.waitKey();
cv2.destroyAllWindows();

# %%
img[60:85,:]=1
img[:,60:85]=1

# %%
cv2.imshow("final",img)
cv2.waitKey();
cv2.destroyAllWindows();

# %%
#Step2 : Load Image
img1=cv2.imread("1.png")
img2=cv2.imread("2.png")

# %%
#Display both image
cv2.imshow("img1",img1);
cv2.imshow("img2",img2);
cv2.waitKey();
cv2.destroyAllWindows();

# %%
img1.shape
# Out:
# (409, 374, 3)

# %%
img2.shape
# Out:
# (737, 600, 3)

# %%
img3=img1[:80,:80]
cv2.imshow('crop_swap' , img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img4=img2[:80,:80]
cv2.imshow('crop_swap' , img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img1[:80,:80]=img4
img2[:80,:80]=0
cv2.imshow('crop_swap1' , img1)
cv2.imshow('crop_swap2' , img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img2[:80,:80]=img3
 
cv2.imshow('crop_swap2' , img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
from PIL import Image

# %%
#Step2 : Load Image
img1=Image.open("1.png")
img2=Image.open("2.png")

# %%
img1 = img1.resize((454 , 350))
img2 = img2.resize((454 , 350))

# %%
img1.size[0]
# Out:
# 454

# %%
new_image = Image.new('RGB',(2*img1.size[0], img1.size[1]), (250,250,250))

# %%
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=908x350 at 0x1F9CBAC8C10>

# %%
new_image.paste(img1)
img1.size[0],0
# Out:
# (454, 0)

# %%
new_image.paste(img2,(img1.size[0],0))

# %%
new_image.save("merge.jpg","JPEG")
new_image.show()

# %%
image_swap = new_image.transpose(Image.FLIP_LEFT_RIGHT)

# %%
image_swap.show()
